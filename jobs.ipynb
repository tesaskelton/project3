# %% [markdown]
# # Import Dependencies

# %%
# !pip install -U googlemaps

# %%
# Dependencies and Setup FOR API
import pandas as pd
import sqlite3 as sql 
from sqlalchemy import create_engine, inspect
import numpy as np
import requests
import time
import datetime as dt
import json

import googlemaps
#from api_keys import g_key

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %% [markdown]
# ## Read and Store Data Science Jobs Salaries CSV file into DataFrame

# %%
# Read and Store linkedin_jobs_usa file into dataframe 
jobs_stats = "data/ds_salary.csv"
jobs_stats_df = pd.read_csv(jobs_stats, index_col=0)
jobs_stats_df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %% [markdown]
# ## Transform the Dataframe

# %%
# Check the null values (if any) in the df
jobs_stats_df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Check for duplicates
jobs_stats_df.duplicated().sum()
# Out:
# 42

# %%
# Check the unique job titles in the df
print(jobs_stats_df['job_title'].nunique())
print(jobs_stats_df['job_title'].unique())
# Out:
# 50
# ['Data Scientist' 'Machine Learning Scientist' 'Big Data Engineer'
#  'Product Data Analyst' 'Machine Learning Engineer' 'Data Analyst'
#  'Lead Data Scientist' 'Business Data Analyst' 'Lead Data Engineer'
#  'Lead Data Analyst' 'Data Engineer' 'Data Science Consultant'
#  'BI Data Analyst' 'Director of Data Science' 'Research Scientist'
#  'Machine Learning Manager' 'Data Engineering Manager'
#  'Machine Learning Infrastructure Engineer' 'ML Engineer' 'AI Scientist'
#  'Computer Vision Engineer' 'Principal Data Scientist'
#  'Data Science Manager' 'Head of Data' '3D Computer Vision Researcher'
#  'Data Analytics Engineer' 'Applied Data Scientist'
#  'Marketing Data Analyst' 'Cloud Data Engineer' 'Financial Data Analyst'
#  'Computer Vision Software Engineer' 'Director of Data Engineering'
#  'Data Science Engineer' 'Principal Data Engineer'
#  'Machine Learning Developer' 'Applied Machine Learning Scientist'
#  'Data Analytics Manager' 'Head of Data Science' 'Data Specialist'
#  'Data Architect' 'Finance Data Analyst' 'Principal Data Analyst'
#  'Big Data Architect' 'Staff Data Scientist' 'Analytics Engineer'
#  'ETL Developer' 'Head of Machine Learning' 'NLP Engineer'
#  'Lead Machine Learning Engineer' 'Data Analytics Lead']

# %%
# Check the unique countries in the df
print(jobs_stats_df['company_location'].nunique())
print(jobs_stats_df['company_location'].unique())
# Out:
# 50
# ['DE' 'JP' 'GB' 'HN' 'US' 'HU' 'NZ' 'FR' 'IN' 'PK' 'CN' 'GR' 'AE' 'NL'
#  'MX' 'CA' 'AT' 'NG' 'ES' 'PT' 'DK' 'IT' 'HR' 'LU' 'PL' 'SG' 'RO' 'IQ'
#  'BR' 'BE' 'UA' 'IL' 'RU' 'MT' 'CL' 'IR' 'CO' 'MD' 'KE' 'SI' 'CH' 'VN'
#  'AS' 'TR' 'CZ' 'DZ' 'EE' 'MY' 'AU' 'IE']

# %%
# Rename the cells of remote_ratio column as 'onsite', 'hybrid' ,'remote' for plotting
jobs_stats_df.remote_ratio.replace([0,50,100], ['onsite', 'hybrid' ,'remote'],inplace = True)
jobs_stats_df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 0   70000             EUR          79833                 DE       onsite
# 1  260000             USD         260000                 JP       onsite
# 2   85000             GBP         109024                 GB       hybrid
# 3   20000             USD          20000                 HN       onsite
# 4  150000             USD         150000                 US       hybrid
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
# Write the df to SQLite database
conn = sql.connect('data/jobstats_db.sqlite')
jobs_stats_df.to_sql('job_stats', conn, if_exists='replace', index=False)
pd.read_sql('select * from job_stats', conn)
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 0     70000             EUR          79833                 DE       onsite
# 1    260000             USD         260000                 JP       onsite
# 2     85000             GBP         109024                 GB       hybrid
# 3     20000             USD          20000                 HN       onsite
# 4    150000             USD         150000                 US       hybrid
# ..      ...             ...            ...                ...          ...
# 602  154000             USD         154000                 US       remote
# 603  126000             USD         126000                 US       remote
# 604  129000             USD         129000                 US       onsite
# 605  150000             USD         150000                 US       remote
# 606  200000             USD         200000                 IN       remote
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 3                 HN            S
# 4                 US            L
# ..               ...          ...
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L
#
# [607 rows x 11 columns]

# %%
pd.read_sql('select count(*), job_title from job_stats group by job_title', conn)
# Out:
#     count(*)                                 job_title
# 0          1             3D Computer Vision Researcher
# 1          7                              AI Scientist
# 2          4                        Analytics Engineer
# 3          5                    Applied Data Scientist
# 4          4        Applied Machine Learning Scientist
# 5          6                           BI Data Analyst
# 6          1                        Big Data Architect
# 7          8                         Big Data Engineer
# 8          5                     Business Data Analyst
# 9          2                       Cloud Data Engineer
# 10         6                  Computer Vision Engineer
# 11         3         Computer Vision Software Engineer
# 12        97                              Data Analyst
# 13         4                   Data Analytics Engineer
# 14         1                       Data Analytics Lead
# 15         7                    Data Analytics Manager
# 16        11                            Data Architect
# 17       132                             Data Engineer
# 18         5                  Data Engineering Manager
# 19         7                   Data Science Consultant
# 20         3                     Data Science Engineer
# 21        12                      Data Science Manager
# 22       143                            Data Scientist
# 23         1                           Data Specialist
# 24         2              Director of Data Engineering
# 25         7                  Director of Data Science
# 26         2                             ETL Developer
# 27         1                      Finance Data Analyst
# 28         2                    Financial Data Analyst
# 29         5                              Head of Data
# 30         4                      Head of Data Science
# 31         1                  Head of Machine Learning
# 32         3                         Lead Data Analyst
# 33         6                        Lead Data Engineer
# 34         3                       Lead Data Scientist
# 35         1            Lead Machine Learning Engineer
# 36         6                               ML Engineer
# 37         3                Machine Learning Developer
# 38        41                 Machine Learning Engineer
# 39         3  Machine Learning Infrastructure Engineer
# 40         1                  Machine Learning Manager
# 41         8                Machine Learning Scientist
# 42         1                    Marketing Data Analyst
# 43         1                              NLP Engineer
# 44         2                    Principal Data Analyst
# 45         3                   Principal Data Engineer
# 46         7                  Principal Data Scientist
# 47         2                      Product Data Analyst
# 48        16                        Research Scientist
# 49         1                      Staff Data Scientist

# %%
conn = sql.connect('data/jobstats_db.sqlite')
cur = conn.cursor()

# %%
word_data = cur.execute('select count(*),job_title from job_stats group by job_title order by count(*) desc').fetchall()

# %%
word_data
# Out:
# [(143, 'Data Scientist'),
#  (132, 'Data Engineer'),
#  (97, 'Data Analyst'),
#  (41, 'Machine Learning Engineer'),
#  (16, 'Research Scientist'),
#  (12, 'Data Science Manager'),
#  (11, 'Data Architect'),
#  (8, 'Machine Learning Scientist'),
#  (8, 'Big Data Engineer'),
#  (7, 'Principal Data Scientist'),
#  (7, 'Director of Data Science'),
#  (7, 'Data Science Consultant'),
#  (7, 'Data Analytics Manager'),
#  (7, 'AI Scientist'),
#  (6, 'ML Engineer'),
#  (6, 'Lead Data Engineer'),
#  (6, 'Computer Vision Engineer'),
#  (6, 'BI Data Analyst'),
#  (5, 'Head of Data'),
#  (5, 'Data Engineering Manager'),
#  (5, 'Business Data Analyst'),
#  (5, 'Applied Data Scientist'),
#  (4, 'Head of Data Science'),
#  (4, 'Data Analytics Engineer'),
#  (4, 'Applied Machine Learning Scientist'),
#  (4, 'Analytics Engineer'),
#  (3, 'Principal Data Engineer'),
#  (3, 'Machine Learning Infrastructure Engineer'),
#  (3, 'Machine Learning Developer'),
#  (3, 'Lead Data Scientist'),
#  (3, 'Lead Data Analyst'),
#  (3, 'Data Science Engineer'),
#  (3, 'Computer Vision Software Engineer'),
#  (2, 'Product Data Analyst'),
#  (2, 'Principal Data Analyst'),
#  (2, 'Financial Data Analyst'),
#  (2, 'ETL Developer'),
#  (2, 'Director of Data Engineering'),
#  (2, 'Cloud Data Engineer'),
#  (1, 'Staff Data Scientist'),
#  (1, 'NLP Engineer'),
#  (1, 'Marketing Data Analyst'),
#  (1, 'Machine Learning Manager'),
#  (1, 'Lead Machine Learning Engineer'),
#  (1, 'Head of Machine Learning'),
#  (1, 'Finance Data Analyst'),
#  (1, 'Data Specialist'),
#  (1, 'Data Analytics Lead'),
#  (1, 'Big Data Architect'),
#  (1, '3D Computer Vision Researcher')]

# %%
jsonString = json.dumps(word_data)

# %%
jsonString
# Out:
# '[[143, "Data Scientist"], [132, "Data Engineer"], [97, "Data Analyst"], [41, "Machine Learning Engineer"], [16, "Research Scientist"], [12, "Data Science Manager"], [11, "Data Architect"], [8, "Machine Learning Scientist"], [8, "Big Data Engineer"], [7, "Principal Data Scientist"], [7, "Director of Data Science"], [7, "Data Science Consultant"], [7, "Data Analytics Manager"], [7, "AI Scientist"], [6, "ML Engineer"], [6, "Lead Data Engineer"], [6, "Computer Vision Engineer"], [6, "BI Data Analyst"], [5, "Head of Data"], [5, "Data Engineering Manager"], [5, "Business Data Analyst"], [5, "Applied Data Scientist"], [4, "Head of Data Science"], [4, "Data Analytics Engineer"], [4, "Applied Machine Learning Scientist"], [4, "Analytics Engineer"], [3, "Principal Data Engineer"], [3, "Machine Learning Infrastructure Engineer"], [3, "Machine Learning Developer"], [3, "Lead Data Scientist"], [3, "Lead Data Analyst"], [3, "Data Science Engineer"], [3, "Computer Vision Software Engineer"], [2, "Product Data Analyst"], [2, "Principal Data Analyst"], [2, "Financial Data Analyst"], [2, "ETL Developer"], [2, "Director of Data Engineering"], [2, "Cloud Data Engineer"], [1, "Staff Data Scientist"], [1, "NLP Engineer"], [1, "Marketing Data Analyst"], [1, "Machine Learning Manager"], [1, "Lead Machine Learning Engineer"], [1, "Head of Machine Learning"], [1, "Finance Data Analyst"], [1, "Data Specialist"], [1, "Data Analytics Lead"], [1, "Big Data Architect"], [1, "3D Computer Vision Researcher"]]'

# %%
num_jobs = cur.execute('select company_location, COUNT(*) from job_stats GROUP BY company_location').fetchall()

# %%
num_jobs
# Out:
# [('AE', 3),
#  ('AS', 1),
#  ('AT', 4),
#  ('AU', 3),
#  ('BE', 2),
#  ('BR', 3),
#  ('CA', 30),
#  ('CH', 2),
#  ('CL', 1),
#  ('CN', 2),
#  ('CO', 1),
#  ('CZ', 2),
#  ('DE', 28),
#  ('DK', 3),
#  ('DZ', 1),
#  ('EE', 1),
#  ('ES', 14),
#  ('FR', 15),
#  ('GB', 47),
#  ('GR', 11),
#  ('HN', 1),
#  ('HR', 1),
#  ('HU', 1),
#  ('IE', 1),
#  ('IL', 1),
#  ('IN', 24),
#  ('IQ', 1),
#  ('IR', 1),
#  ('IT', 2),
#  ('JP', 6),
#  ('KE', 1),
#  ('LU', 3),
#  ('MD', 1),
#  ('MT', 1),
#  ('MX', 3),
#  ('MY', 1),
#  ('NG', 2),
#  ('NL', 4),
#  ('NZ', 1),
#  ('PK', 3),
#  ('PL', 4),
#  ('PT', 4),
#  ('RO', 1),
#  ('RU', 2),
#  ('SG', 1),
#  ('SI', 2),
#  ('TR', 3),
#  ('UA', 1),
#  ('US', 355),
#  ('VN', 1)]

# %%
num_jobs_list = []

for country, job_count in num_jobs:
    num_jobs_dict = {}
    num_jobs_dict["Name"] = country
    num_jobs_dict["Count"] = job_count
    num_jobs_list.append(num_jobs_dict)

# %%
bubble_dict ={}
bubble_dict["children"] = num_jobs_list
bubble_dict
# Out:
# {'children': [{'Name': 'AE', 'Count': 3},
#   {'Name': 'AS', 'Count': 1},
#   {'Name': 'AT', 'Count': 4},
#   {'Name': 'AU', 'Count': 3},
#   {'Name': 'BE', 'Count': 2},
#   {'Name': 'BR', 'Count': 3},
#   {'Name': 'CA', 'Count': 30},
#   {'Name': 'CH', 'Count': 2},
#   {'Name': 'CL', 'Count': 1},
#   {'Name': 'CN', 'Count': 2},
#   {'Name': 'CO', 'Count': 1},
#   {'Name': 'CZ', 'Count': 2},
#   {'Name': 'DE', 'Count': 28},
#   {'Name': 'DK', 'Count': 3},
#   {'Name': 'DZ', 'Count': 1},
#   {'Name': 'EE', 'Count': 1},
#   {'Name': 'ES', 'Count': 14},
#   {'Name': 'FR', 'Count': 15},
#   {'Name': 'GB', 'Count': 47},
#   {'Name': 'GR', 'Count': 11},
#   {'Name': 'HN', 'Count': 1},
#   {'Name': 'HR', 'Count': 1},
#   {'Name': 'HU', 'Count': 1},
#   {'Name': 'IE', 'Count': 1},
#   {'Name': 'IL', 'Count': 1},
#   {'Name': 'IN', 'Count': 24},
#   {'Name': 'IQ', 'Count': 1},
#   {'Name': 'IR', 'Count': 1},
#   {'Name': 'IT', 'Count': 2},
#   {'Name': 'JP', 'Count': 6},
#   {'Name': 'KE', 'Count': 1},
#   {'Name': 'LU', 'Count': 3},
#   {'Name': 'MD', 'Count': 1},
#   {'Name': 'MT', 'Count': 1},
#   {'Name': 'MX', 'Count': 3},
#   {'Name': 'MY', 'Count': 1},
#   {'Name': 'NG', 'Count': 2},
#   {'Name': 'NL', 'Count': 4},
#   {'Name': 'NZ', 'Count': 1},
#   {'Name': 'PK', 'Count': 3},
#   {'Name': 'PL', 'Count': 4},
#   {'Name': 'PT', 'Count': 4},
#   {'Name': 'RO', 'Count': 1},
#   {'Name': 'RU', 'Count': 2},
#   {'Name': 'SG', 'Count': 1},
#   {'Name': 'SI', 'Count': 2},
#   {'Name': 'TR', 'Count': 3},
#   {'Name': 'UA', 'Count': 1},
#   {'Name': 'US', 'Count': 355},
#   {'Name': 'VN', 'Count': 1}]}

# %%
country_jobs_dict = bubble_dict
country_jobs_dict
# Out:
# {'children': [{'Name': 'AE', 'Count': 3},
#   {'Name': 'AS', 'Count': 1},
#   {'Name': 'AT', 'Count': 4},
#   {'Name': 'AU', 'Count': 3},
#   {'Name': 'BE', 'Count': 2},
#   {'Name': 'BR', 'Count': 3},
#   {'Name': 'CA', 'Count': 30},
#   {'Name': 'CH', 'Count': 2},
#   {'Name': 'CL', 'Count': 1},
#   {'Name': 'CN', 'Count': 2},
#   {'Name': 'CO', 'Count': 1},
#   {'Name': 'CZ', 'Count': 2},
#   {'Name': 'DE', 'Count': 28},
#   {'Name': 'DK', 'Count': 3},
#   {'Name': 'DZ', 'Count': 1},
#   {'Name': 'EE', 'Count': 1},
#   {'Name': 'ES', 'Count': 14},
#   {'Name': 'FR', 'Count': 15},
#   {'Name': 'GB', 'Count': 47},
#   {'Name': 'GR', 'Count': 11},
#   {'Name': 'HN', 'Count': 1},
#   {'Name': 'HR', 'Count': 1},
#   {'Name': 'HU', 'Count': 1},
#   {'Name': 'IE', 'Count': 1},
#   {'Name': 'IL', 'Count': 1},
#   {'Name': 'IN', 'Count': 24},
#   {'Name': 'IQ', 'Count': 1},
#   {'Name': 'IR', 'Count': 1},
#   {'Name': 'IT', 'Count': 2},
#   {'Name': 'JP', 'Count': 6},
#   {'Name': 'KE', 'Count': 1},
#   {'Name': 'LU', 'Count': 3},
#   {'Name': 'MD', 'Count': 1},
#   {'Name': 'MT', 'Count': 1},
#   {'Name': 'MX', 'Count': 3},
#   {'Name': 'MY', 'Count': 1},
#   {'Name': 'NG', 'Count': 2},
#   {'Name': 'NL', 'Count': 4},
#   {'Name': 'NZ', 'Count': 1},
#   {'Name': 'PK', 'Count': 3},
#   {'Name': 'PL', 'Count': 4},
#   {'Name': 'PT', 'Count': 4},
#   {'Name': 'RO', 'Count': 1},
#   {'Name': 'RU', 'Count': 2},
#   {'Name': 'SG', 'Count': 1},
#   {'Name': 'SI', 'Count': 2},
#   {'Name': 'TR', 'Count': 3},
#   {'Name': 'UA', 'Count': 1},
#   {'Name': 'US', 'Count': 355},
#   {'Name': 'VN', 'Count': 1}]}

# %%
country_jobs_dict = {'children': [{'Name': 'AE', 'Count': 3},
  {'Name': 'AS', 'Count': 1},
  {'Name': 'AT', 'Count': 4},
  {'Name': 'AU', 'Count': 3},
  {'Name': 'BE', 'Count': 2},
  {'Name': 'BR', 'Count': 3},
  {'Name': 'CA', 'Count': 30},
  {'Name': 'CH', 'Count': 2},
  {'Name': 'CL', 'Count': 1},
  {'Name': 'CN', 'Count': 2},
  {'Name': 'CO', 'Count': 1},
  {'Name': 'CZ', 'Count': 2},
  {'Name': 'DE', 'Count': 28},
  {'Name': 'DK', 'Count': 3},
  {'Name': 'DZ', 'Count': 1},
  {'Name': 'EE', 'Count': 1},
  {'Name': 'ES', 'Count': 14},
  {'Name': 'FR', 'Count': 15},
  {'Name': 'GB', 'Count': 47},
  {'Name': 'GR', 'Count': 11},
  {'Name': 'HN', 'Count': 1},
  {'Name': 'HR', 'Count': 1},
  {'Name': 'HU', 'Count': 1},
  {'Name': 'IE', 'Count': 1},
  {'Name': 'IL', 'Count': 1},
  {'Name': 'IN', 'Count': 24},
  {'Name': 'IQ', 'Count': 1},
  {'Name': 'IR', 'Count': 1},
  {'Name': 'IT', 'Count': 2},
  {'Name': 'JP', 'Count': 6},
  {'Name': 'KE', 'Count': 1},
  {'Name': 'LU', 'Count': 3},
  {'Name': 'MD', 'Count': 1},
  {'Name': 'MT', 'Count': 1},
  {'Name': 'MX', 'Count': 3},
  {'Name': 'MY', 'Count': 1},
  {'Name': 'NG', 'Count': 2},
  {'Name': 'NL', 'Count': 4},
  {'Name': 'NZ', 'Count': 1},
  {'Name': 'PK', 'Count': 3},
  {'Name': 'PL', 'Count': 4},
  {'Name': 'PT', 'Count': 4},
  {'Name': 'RO', 'Count': 1},
  {'Name': 'RU', 'Count': 2},
  {'Name': 'SG', 'Count': 1},
  {'Name': 'SI', 'Count': 2},
  {'Name': 'TR', 'Count': 3},
  {'Name': 'UA', 'Count': 1},
  {'Name': 'US', 'Count': 355},
  {'Name': 'VN', 'Count': 1}]}

# %%
country_jobs_dict
# Out:
# {'children': [{'Name': 'AE', 'Count': 3},
#   {'Name': 'AS', 'Count': 1},
#   {'Name': 'AT', 'Count': 4},
#   {'Name': 'AU', 'Count': 3},
#   {'Name': 'BE', 'Count': 2},
#   {'Name': 'BR', 'Count': 3},
#   {'Name': 'CA', 'Count': 30},
#   {'Name': 'CH', 'Count': 2},
#   {'Name': 'CL', 'Count': 1},
#   {'Name': 'CN', 'Count': 2},
#   {'Name': 'CO', 'Count': 1},
#   {'Name': 'CZ', 'Count': 2},
#   {'Name': 'DE', 'Count': 28},
#   {'Name': 'DK', 'Count': 3},
#   {'Name': 'DZ', 'Count': 1},
#   {'Name': 'EE', 'Count': 1},
#   {'Name': 'ES', 'Count': 14},
#   {'Name': 'FR', 'Count': 15},
#   {'Name': 'GB', 'Count': 47},
#   {'Name': 'GR', 'Count': 11},
#   {'Name': 'HN', 'Count': 1},
#   {'Name': 'HR', 'Count': 1},
#   {'Name': 'HU', 'Count': 1},
#   {'Name': 'IE', 'Count': 1},
#   {'Name': 'IL', 'Count': 1},
#   {'Name': 'IN', 'Count': 24},
#   {'Name': 'IQ', 'Count': 1},
#   {'Name': 'IR', 'Count': 1},
#   {'Name': 'IT', 'Count': 2},
#   {'Name': 'JP', 'Count': 6},
#   {'Name': 'KE', 'Count': 1},
#   {'Name': 'LU', 'Count': 3},
#   {'Name': 'MD', 'Count': 1},
#   {'Name': 'MT', 'Count': 1},
#   {'Name': 'MX', 'Count': 3},
#   {'Name': 'MY', 'Count': 1},
#   {'Name': 'NG', 'Count': 2},
#   {'Name': 'NL', 'Count': 4},
#   {'Name': 'NZ', 'Count': 1},
#   {'Name': 'PK', 'Count': 3},
#   {'Name': 'PL', 'Count': 4},
#   {'Name': 'PT', 'Count': 4},
#   {'Name': 'RO', 'Count': 1},
#   {'Name': 'RU', 'Count': 2},
#   {'Name': 'SG', 'Count': 1},
#   {'Name': 'SI', 'Count': 2},
#   {'Name': 'TR', 'Count': 3},
#   {'Name': 'UA', 'Count': 1},
#   {'Name': 'US', 'Count': 355},
#   {'Name': 'VN', 'Count': 1}]}

# %%
dict =  json.dumps(num_jobs_list)
dict
# Out:
# '[{"Name": "AE", "Count": 3}, {"Name": "AS", "Count": 1}, {"Name": "AT", "Count": 4}, {"Name": "AU", "Count": 3}, {"Name": "BE", "Count": 2}, {"Name": "BR", "Count": 3}, {"Name": "CA", "Count": 30}, {"Name": "CH", "Count": 2}, {"Name": "CL", "Count": 1}, {"Name": "CN", "Count": 2}, {"Name": "CO", "Count": 1}, {"Name": "CZ", "Count": 2}, {"Name": "DE", "Count": 28}, {"Name": "DK", "Count": 3}, {"Name": "DZ", "Count": 1}, {"Name": "EE", "Count": 1}, {"Name": "ES", "Count": 14}, {"Name": "FR", "Count": 15}, {"Name": "GB", "Count": 47}, {"Name": "GR", "Count": 11}, {"Name": "HN", "Count": 1}, {"Name": "HR", "Count": 1}, {"Name": "HU", "Count": 1}, {"Name": "IE", "Count": 1}, {"Name": "IL", "Count": 1}, {"Name": "IN", "Count": 24}, {"Name": "IQ", "Count": 1}, {"Name": "IR", "Count": 1}, {"Name": "IT", "Count": 2}, {"Name": "JP", "Count": 6}, {"Name": "KE", "Count": 1}, {"Name": "LU", "Count": 3}, {"Name": "MD", "Count": 1}, {"Name": "MT", "Count": 1}, {"Name": "MX", "Count": 3}, {"Name": "MY", "Count": 1}, {"Name": "NG", "Count": 2}, {"Name": "NL", "Count": 4}, {"Name": "NZ", "Count": 1}, {"Name": "PK", "Count": 3}, {"Name": "PL", "Count": 4}, {"Name": "PT", "Count": 4}, {"Name": "RO", "Count": 1}, {"Name": "RU", "Count": 2}, {"Name": "SG", "Count": 1}, {"Name": "SI", "Count": 2}, {"Name": "TR", "Count": 3}, {"Name": "UA", "Count": 1}, {"Name": "US", "Count": 355}, {"Name": "VN", "Count": 1}]'

# %%
for country, job_count in country_data:
  num_jobs_dict["name","value"] = country,job_count

# %%
num_jobs_dict
# Out:
# {'name': ('VN',), 'value': 1, ('name', 'value'): ('VN', 1)}

# %%
jsonString = json.dumps(country_data)

# %%
jsonString
# Out:
# '[["AE", 3], ["AS", 1], ["AT", 4], ["AU", 3], ["BE", 2], ["BR", 3], ["CA", 30], ["CH", 2], ["CL", 1], ["CN", 2], ["CO", 1], ["CZ", 2], ["DE", 28], ["DK", 3], ["DZ", 1], ["EE", 1], ["ES", 14], ["FR", 15], ["GB", 47], ["GR", 11], ["HN", 1], ["HR", 1], ["HU", 1], ["IE", 1], ["IL", 1], ["IN", 24], ["IQ", 1], ["IR", 1], ["IT", 2], ["JP", 6], ["KE", 1], ["LU", 3], ["MD", 1], ["MT", 1], ["MX", 3], ["MY", 1], ["NG", 2], ["NL", 4], ["NZ", 1], ["PK", 3], ["PL", 4], ["PT", 4], ["RO", 1], ["RU", 2], ["SG", 1], ["SI", 2], ["TR", 3], ["UA", 1], ["US", 355], ["VN", 1]]'

# %%
num_jobs = cur.execute('select job_title, count(job_title), AVG(salary_in_usd) from job_stats GROUP BY job_title order by count(job_title) desc limit 10').fetchall()
num_jobs
# Out:
# [('Data Scientist', 143, 108187.83216783217),
#  ('Data Engineer', 132, 112725.0),
#  ('Data Analyst', 97, 92893.06185567011),
#  ('Machine Learning Engineer', 41, 104880.14634146342),
#  ('Research Scientist', 16, 109019.5),
#  ('Data Science Manager', 12, 158328.5),
#  ('Data Architect', 11, 177873.9090909091),
#  ('Machine Learning Scientist', 8, 158412.5),
#  ('Big Data Engineer', 8, 51974.0),
#  ('Principal Data Scientist', 7, 215242.42857142858)]

# %% [markdown]
# ## Read and Store USA jobs CSV file into DataFrame

# %%
# Read and Store linkedin_jobs_usa file into dataframe 
jobs_usa = "data/linkedin_jobs_usa.csv"
jobs_usa_df = pd.read_csv(jobs_usa)
jobs_usa_df.head()
# Out:
#                             title                   company  \
# 0  Data Analyst - Recent Graduate                    PayPal
# 1  Data Analyst - Recent Graduate                    PayPal
# 2                    Data Analyst                    PayPal
# 3                    Data Analyst                    PayPal
# 4        Entry-Level Data Analyst  The Federal Savings Bank
#
#                                          description onsite_remote salary  \
# 0  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 1  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 2  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 3  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 4  The Federal Savings Bank, a national bank and ...        onsite    NaN
#
#                      location  \
# 0  Buffalo-Niagara Falls Area
# 1                San Jose, CA
# 2        Texas, United States
# 3     Illinois, United States
# 4                 Chicago, IL
#
#                                             criteria posted_date  \
# 0  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-22
# 1  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-22
# 2  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-17
# 3  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-17
# 4  [{'Seniority level': 'Entry level'}, {'Employm...  2022-11-17
#
#                                                 link
# 0  https://www.linkedin.com/jobs/view/data-analys...
# 1  https://www.linkedin.com/jobs/view/data-analys...
# 2  https://www.linkedin.com/jobs/view/data-analys...
# 3  https://www.linkedin.com/jobs/view/data-analys...
# 4  https://www.linkedin.com/jobs/view/entry-level...

# %% [markdown]
# ## Transform the DataFrame

# %% [markdown]
# ### Add coordinates of the locations using Googlemaps

# %%
# gmaps = googlemaps.Client(key= g_key)

# jobs_usa_df['latitude'] = None
# jobs_usa_df['longitude'] = None

# for i in range(0, len(jobs_usa_df)):     
#     try:        
        
#         geocode_result = gmaps.geocode(jobs_usa_df.iat[i, 5])
#         lat= geocode_result[0]['geometry']['location']['lat']
#         lng= geocode_result[0]['geometry']['location']['lng']
#         jobs_usa_df.iat[i, jobs_usa_df.columns.get_loc('latitude')] = lat
#         jobs_usa_df.iat[i, jobs_usa_df.columns.get_loc('longitude')] = lng
        
#     except Exception as e:
#         print(e)
        
# jobs_usa_df
# Out:
# list index out of range
# list index out of range
#                                title                   company  \
# 0     Data Analyst - Recent Graduate                    PayPal
# 1     Data Analyst - Recent Graduate                    PayPal
# 2                       Data Analyst                    PayPal
# 3                       Data Analyst                    PayPal
# 4           Entry-Level Data Analyst  The Federal Savings Bank
# ...                              ...                       ...
# 2840             Junior Data Analyst        Iris Software Inc.
# 2841              Data Analyst (SQL)             Marwood Group
# 2842                    Data Analyst        SmartSense by Digi
# 2843                    Data Analyst            Synergy Search
# 2844                    Data Analyst            Insight Global
#
#                                             description onsite_remote  \
# 0     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 1     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 2     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 3     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 4     The Federal Savings Bank, a national bank and ...        onsite
# ...                                                 ...           ...
# 2840  Iris's client, one of the world's largest fina...        hybrid
# 2841  The Marwood Group (Marwood) is a leading healt...        hybrid
# 2842  Join a high-performing, tight-knit team at a f...        hybrid
# 2843  Nashville (Berry Hill) based company looking t...        hybrid
# 2844  Overview - Minimum 5 years in a quantitative d...        hybrid
#
#                                                  salary  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2840                                                NaN
# 2841  $75,000.00\r\n            -\r\n            $95...
# 2842                                                NaN
# 2843  $85,000.00\r\n            -\r\n            $95...
# 2844  $130,000.00\r\n            -\r\n            $1...
#
#                              location  \
# 0          Buffalo-Niagara Falls Area
# 1                        San Jose, CA
# 2                Texas, United States
# 3             Illinois, United States
# 4                         Chicago, IL
# ...                               ...
# 2840             Texas, United States
# 2841  New York City Metropolitan Area
# 2842                    Mishawaka, IN
# 2843      Nashville Metropolitan Area
# 2844                      Burbank, CA
#
#                                                criteria posted_date  \
# 0     [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-22
# 1     [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-22
# 2     [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-17
# 3     [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-17
# 4     [{'Seniority level': 'Entry level'}, {'Employm...  2022-11-17
# ...                                                 ...         ...
# 2840  [{'Seniority level': 'Mid-Senior level'}, {'Em...  2022-10-21
# 2841  [{'Seniority level': 'Mid-Senior level'}, {'Em...  2022-10-26
# 2842  [{'Seniority level': 'Associate'}, {'Employmen...  2022-11-17
# 2843  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-14
# 2844  [{'Seniority level': 'Mid-Senior level'}, {'Em...  2022-11-14
#
#                                                    link   latitude   longitude
# 0     https://www.linkedin.com/jobs/view/data-analys...  42.851801  -78.747621
# 1     https://www.linkedin.com/jobs/view/data-analys...   37.33874 -121.885253
# 2     https://www.linkedin.com/jobs/view/data-analys...  31.968599  -99.901813
# 3     https://www.linkedin.com/jobs/view/data-analys...  40.633125  -89.398528
# 4     https://www.linkedin.com/jobs/view/entry-level...  41.878114  -87.629798
# ...                                                 ...        ...         ...
# 2840  https://www.linkedin.com/jobs/view/junior-data...  31.968599  -99.901813
# 2841  https://www.linkedin.com/jobs/view/data-analys...  40.712776  -74.005954
# 2842  https://www.linkedin.com/jobs/view/data-analys...  41.661993  -86.158616
# 2843  https://www.linkedin.com/jobs/view/data-analys...  36.162646  -86.781497
# 2844  https://www.linkedin.com/jobs/view/data-analys...  34.180839 -118.308966
#
# [2845 rows x 11 columns]

# %% [markdown]
# ### Save the updated dataframe as csv file

# %%
#  Save the new dataframe as CSV file and use this file for further use so that we are not makining the api call again
# jobs_usa_df.to_csv('data/updated_jobs_usa.csv')

# %% [markdown]
# ### Read and Store the updated CSV file into DataFrame

# %%
# Read and Store updated_jobs_usa file into dataframe 
updated_jobs_usa = "data/updated_jobs_usa.csv"
updated_jobs_usa_df = pd.read_csv(updated_jobs_usa, index_col=0)
updated_jobs_usa_df.head()
# Out:
#                             title                   company  \
# 0  Data Analyst - Recent Graduate                    PayPal
# 1  Data Analyst - Recent Graduate                    PayPal
# 2                    Data Analyst                    PayPal
# 3                    Data Analyst                    PayPal
# 4        Entry-Level Data Analyst  The Federal Savings Bank
#
#                                          description onsite_remote salary  \
# 0  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 1  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 2  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 3  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 4  The Federal Savings Bank, a national bank and ...        onsite    NaN
#
#                      location  \
# 0  Buffalo-Niagara Falls Area
# 1                San Jose, CA
# 2        Texas, United States
# 3     Illinois, United States
# 4                 Chicago, IL
#
#                                             criteria posted_date  \
# 0  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-22
# 1  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-22
# 2  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-17
# 3  [{'Seniority level': 'Not Applicable'}, {'Empl...  2022-11-17
# 4  [{'Seniority level': 'Entry level'}, {'Employm...  2022-11-17
#
#                                                 link   latitude   longitude
# 0  https://www.linkedin.com/jobs/view/data-analys...  42.851801  -78.747621
# 1  https://www.linkedin.com/jobs/view/data-analys...  37.338740 -121.885253
# 2  https://www.linkedin.com/jobs/view/data-analys...  31.968599  -99.901813
# 3  https://www.linkedin.com/jobs/view/data-analys...  40.633125  -89.398528
# 4  https://www.linkedin.com/jobs/view/entry-level...  41.878114  -87.629798

# %%
# Drop unwanted columns from the df
updated_jobs_usa_df = updated_jobs_usa_df.drop(columns=['criteria', 'description', 'salary'])


# Remane columns
updated_jobs_usa_df.rename(columns={'onsite_remote':'work_environment'}, inplace = True)

# Drop NaN values
updated_jobs_usa_df = updated_jobs_usa_df.dropna(subset=['latitude', 'longitude'])

# %%
# Convert lattitude and longitude to float types
updated_jobs_usa_df['latitude'] = updated_jobs_usa_df['latitude'].astype(float)
updated_jobs_usa_df['longitude'] = updated_jobs_usa_df['longitude'].astype(float)

# reset index 
updated_jobs_usa_df.reset_index(drop=True)
updated_jobs_usa_df.head()
# Out:
#                             title                   company work_environment  \
# 0  Data Analyst - Recent Graduate                    PayPal           onsite
# 1  Data Analyst - Recent Graduate                    PayPal           onsite
# 2                    Data Analyst                    PayPal           onsite
# 3                    Data Analyst                    PayPal           onsite
# 4        Entry-Level Data Analyst  The Federal Savings Bank           onsite
#
#                      location posted_date  \
# 0  Buffalo-Niagara Falls Area  2022-11-22
# 1                San Jose, CA  2022-11-22
# 2        Texas, United States  2022-11-17
# 3     Illinois, United States  2022-11-17
# 4                 Chicago, IL  2022-11-17
#
#                                                 link   latitude   longitude
# 0  https://www.linkedin.com/jobs/view/data-analys...  42.851801  -78.747621
# 1  https://www.linkedin.com/jobs/view/data-analys...  37.338740 -121.885253
# 2  https://www.linkedin.com/jobs/view/data-analys...  31.968599  -99.901813
# 3  https://www.linkedin.com/jobs/view/data-analys...  40.633125  -89.398528
# 4  https://www.linkedin.com/jobs/view/entry-level...  41.878114  -87.629798

# %%
# Write the df to SQLite database
conn = sql.connect('data/updated_jobs_usa_db.sqlite')
updated_jobs_usa_df.to_sql('updated_jobs_usa', conn, if_exists='replace', index=False)
pd.read_sql('select * from updated_jobs_usa', conn)
# Out:
#                                title                   company  \
# 0     Data Analyst - Recent Graduate                    PayPal
# 1     Data Analyst - Recent Graduate                    PayPal
# 2                       Data Analyst                    PayPal
# 3                       Data Analyst                    PayPal
# 4           Entry-Level Data Analyst  The Federal Savings Bank
# ...                              ...                       ...
# 2838             Junior Data Analyst        Iris Software Inc.
# 2839              Data Analyst (SQL)             Marwood Group
# 2840                    Data Analyst        SmartSense by Digi
# 2841                    Data Analyst            Synergy Search
# 2842                    Data Analyst            Insight Global
#
#      work_environment                         location posted_date  \
# 0              onsite       Buffalo-Niagara Falls Area  2022-11-22
# 1              onsite                     San Jose, CA  2022-11-22
# 2              onsite             Texas, United States  2022-11-17
# 3              onsite          Illinois, United States  2022-11-17
# 4              onsite                      Chicago, IL  2022-11-17
# ...               ...                              ...         ...
# 2838           hybrid             Texas, United States  2022-10-21
# 2839           hybrid  New York City Metropolitan Area  2022-10-26
# 2840           hybrid                    Mishawaka, IN  2022-11-17
# 2841           hybrid      Nashville Metropolitan Area  2022-11-14
# 2842           hybrid                      Burbank, CA  2022-11-14
#
#                                                    link   latitude   longitude
# 0     https://www.linkedin.com/jobs/view/data-analys...  42.851801  -78.747621
# 1     https://www.linkedin.com/jobs/view/data-analys...  37.338740 -121.885253
# 2     https://www.linkedin.com/jobs/view/data-analys...  31.968599  -99.901813
# 3     https://www.linkedin.com/jobs/view/data-analys...  40.633125  -89.398528
# 4     https://www.linkedin.com/jobs/view/entry-level...  41.878114  -87.629798
# ...                                                 ...        ...         ...
# 2838  https://www.linkedin.com/jobs/view/junior-data...  31.968599  -99.901813
# 2839  https://www.linkedin.com/jobs/view/data-analys...  40.712776  -74.005954
# 2840  https://www.linkedin.com/jobs/view/data-analys...  41.661993  -86.158616
# 2841  https://www.linkedin.com/jobs/view/data-analys...  36.162646  -86.781497
# 2842  https://www.linkedin.com/jobs/view/data-analys...  34.180839 -118.308966
#
# [2843 rows x 8 columns]

# %% [markdown]
# ## Convert the Dataframe into Geojson and save as .js file

# %%
# Create a function to convert the dataframe into geojson
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    
    # Create a new python dict to contain the geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # Loop through each row in the dataframe and convert each row to geojson format
    for _, row in df.iterrows():
        
        # Create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # Fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # For each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # Add this feature to the list of features inside the dict
        geojson['features'].append(feature)
    
    return geojson

# %%
# Pass in the dataFrame, list of columns to to the above function
cols = ['title', 'company', 'work_environment', 'location', 'posted_date', 'link']
geojson = df_to_geojson(updated_jobs_usa_df, cols)
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Buffalo-Niagara Falls Area',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364471019?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=Wl5idVe67zjIVZhL%2BbpNOA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-78.74762079999999, 42.8518007]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'San Jose, CA',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364467390?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=3IOGqlhBDgIdKd%2F48MX8BA%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.8852525, 37.33874]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Texas, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608136?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=5WUZto5yfhI%2Fgsx5K0rXCA%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-99.9018131, 31.9685988]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Illinois, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605652?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=V8EZKEKWhdCjb3SPQhyXXg%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3985283, 40.6331249]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Entry-Level Data Analyst',
#     'company': 'The Federal Savings Bank',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/entry-level-data-analyst-at-the-federal-savings-bank-3364619835?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=32J%2FNinUpIAKA77Fz4c%2BAw%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Greater Scranton Area',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359603975?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=D0H35C0NOt2nvxb97A4wPA%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.66241219999999, 41.408969]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Tennessee, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359607287?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=%2FmfTSdfrxV057ji7WdfY6Q%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.5804473, 35.5174913]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Indiana, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608137?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=WfyMfqn%2FL8sg2%2Bz2WZYIlw%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.1349019, 40.2671941]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'London Approach',
#     'work_environment': 'onsite',
#     'location': 'Franklin, TN',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-london-approach-3358861203?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=9PyvYSdfQxwZH6rUYZJw8g%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.8688899, 35.9250637]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wisconsin, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605653?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=OrjCB2MzuqFyD0W6LYnlJQ%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7878678, 43.7844397]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Virginia, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359604765?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=5ECj1i%2FN7snidMoLOTV8Gw%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.6568942, 37.4315734]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Omaha, NE',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364469255?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=QimQ7x5wYRN9eh3bVvSWJw%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.9345034, 41.2565369]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Motley Rice',
#     'work_environment': 'onsite',
#     'location': 'Mount Pleasant, SC',
#     'posted_date': '2022-11-15',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-motley-rice-3354985380?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=vWwUht503HId9nWulHd6tg%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.82842579999999, 32.8323225]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wilmington, DE',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359606410?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=sxm5l0pBzinzWR%2FSNPl5cQ%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-75.5483909, 39.744655]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Annapolis, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357037326?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=y%2BbxH%2Bvqm6vHcpVY8tfwCg%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4921829, 38.9784453]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357036349?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=vH%2BV4aw9cTiUaGhAPkk4cA%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6123884, 39.4354087]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': "Chicago Teachers' Pension Fund",
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-19',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-chicago-teachers-%E2%80%8B-pension-fund-3367612394?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=uw5G6mCfcg6hgI5uha6s2A%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'FreightPlus',
#     'work_environment': 'onsite',
#     'location': 'Quincy, MA',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-freightplus-3369469960?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=Jej7EcYeuv%2FLjhADkXjemA%3D%3D&position=18&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.0022705, 42.2528772]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Lockheed Martin',
#     'work_environment': 'onsite',
#     'location': 'Manassas, VA',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-lockheed-martin-3371249347?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=2WYC0m3rjs%2FGqFpogDMDiw%3D%3D&position=19&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.47526669999999, 38.7509488]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Valon',
#     'work_environment': 'onsite',
#     'location': 'New York, NY',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-valon-3365948152?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=NCkNv3XTmMGb8vdnhJ8kjg%3D%3D&position=20&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0059728, 40.7127753]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'MV Realty',
#     'work_environment': 'onsite',
#     'location': 'Delray Beach, FL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-mv-realty-3360506601?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=OyBHj2OaVcE66w6pXRQCog%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-80.0728201, 26.4614625]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Selby Jennings',
#     'work_environment': 'onsite',
#     'location': 'Houston, TX',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-selby-jennings-3370840165?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=Pxy61qy%2F2YyyM993QPd5sQ%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.3698028, 29.7604267]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': '24 Seven Talent',
#     'work_environment': 'onsite',
#     'location': 'Irvine, CA',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-24-seven-talent-3358666710?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=6cYywt6rSaOGQqEFDTrWyA%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8265049, 33.6845673]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Analyst (Global Data and Analytics)',
#     'company': 'Circle K',
#     'work_environment': 'onsite',
#     'location': 'Tempe, AZ',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/analyst-global-data-and-analytics-at-circle-k-3371237584?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=Uc02YUAPzbqPN2sMDEdlFg%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400054, 33.4255104]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Eva Garland Consulting, LLC',
#     'work_environment': 'onsite',
#     'location': 'Raleigh, NC',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-eva-garland-consulting-llc-3370997321?refId=7aKV74baVvH%2FRwNOmaw%2ByA%3D%3D&trackingId=HkeebI8DPbQmrYZlDhhz1A%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.6381787, 35.7795897]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Buffalo-Niagara Falls Area',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364471019?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=CgChfHPVOGBoUO%2FwS5qepA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-78.74762079999999, 42.8518007]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364468404?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=QoIbdmXiaXuCiFkAO4Z3pg%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'San Jose, CA',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364467390?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=1BEEiybyTkM3W7xE%2BmWQcw%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.8852525, 37.33874]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Texas, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608136?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=cemV79DCapy5Abmm9663bg%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-99.9018131, 31.9685988]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Illinois, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605652?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=C95CQnLWcsJJ1bwspxiyRw%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3985283, 40.6331249]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Entry-Level Data Analyst',
#     'company': 'The Federal Savings Bank',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/entry-level-data-analyst-at-the-federal-savings-bank-3364619835?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=R%2BuYxULOLDwlK%2FS763A6XA%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364466578?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=q7sanGL80qy%2FlwNnrcXppA%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6123884, 39.4354087]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Greater Scranton Area',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359603975?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=czRqYqoNMReHO4aaOcFjTQ%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.66241219999999, 41.408969]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Tennessee, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359607287?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=jNar6Yhsq9vX6Nbr9Hy2Vw%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.5804473, 35.5174913]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Indiana, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608137?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=A2ygVzUHJaZoJLYZj3fyvw%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.1349019, 40.2671941]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'London Approach',
#     'work_environment': 'onsite',
#     'location': 'Franklin, TN',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-london-approach-3358861203?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=HjxCG2iUDSnAVk%2BtyZS9Iw%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.8688899, 35.9250637]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wisconsin, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605653?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=d6nQ5raH5urS2vddF5%2FJMQ%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7878678, 43.7844397]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Virginia, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359604765?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=Y0kNBfvsvXi%2BEeV7crgdJQ%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.6568942, 37.4315734]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Omaha, NE',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364469255?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=yEM49KphKpecOROIzc0HFA%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.9345034, 41.2565369]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wilmington, DE',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359606410?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=RrdwYqLhdOH%2BDureLOwswg%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-75.5483909, 39.744655]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Annapolis, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357037326?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=wDBwHWDipnSAb2ovc5P7jQ%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4921829, 38.9784453]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357036349?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=tIAR5tcEmVVvSHvcheIFXg%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6123884, 39.4354087]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': "Chicago Teachers' Pension Fund",
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-19',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-chicago-teachers-%E2%80%8B-pension-fund-3367612394?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=Cl78um7IzY%2FT%2FNC9HrCSeg%3D%3D&position=18&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'FreightPlus',
#     'work_environment': 'onsite',
#     'location': 'Quincy, MA',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-freightplus-3369469960?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=atm5r5UmdYGfvJ05IKENbg%3D%3D&position=19&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.0022705, 42.2528772]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Lockheed Martin',
#     'work_environment': 'onsite',
#     'location': 'Manassas, VA',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-lockheed-martin-3371249347?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=jljrc2JqFHyUkF13XqMzkQ%3D%3D&position=20&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.47526669999999, 38.7509488]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Valon',
#     'work_environment': 'onsite',
#     'location': 'New York, NY',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-valon-3365948152?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=HsmjnAFGRF5oBsBjhptjDw%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0059728, 40.7127753]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'MV Realty',
#     'work_environment': 'onsite',
#     'location': 'Delray Beach, FL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-mv-realty-3360506601?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=7ZMIjDTHU7qXqZVfRFgNqw%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-80.0728201, 26.4614625]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Selby Jennings',
#     'work_environment': 'onsite',
#     'location': 'Houston, TX',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-selby-jennings-3370840165?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=eiwoTQOmsLO2i528K%2FV7Qg%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.3698028, 29.7604267]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': '24 Seven Talent',
#     'work_environment': 'onsite',
#     'location': 'Irvine, CA',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-24-seven-talent-3358666710?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=D22psi8TUTUarHGms%2F%2Buaw%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8265049, 33.6845673]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Analyst (Global Data and Analytics)',
#     'company': 'Circle K',
#     'work_environment': 'onsite',
#     'location': 'Tempe, AZ',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/analyst-global-data-and-analytics-at-circle-k-3371237584?refId=pqDQ2g6BkMrTWMjuTeGHXw%3D%3D&trackingId=61BAdIgp%2FkCpPlw4A5Kl6A%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400054, 33.4255104]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Buffalo-Niagara Falls Area',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364471019?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=MV5nHKU6i1xTnlOs0TCyIQ%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-78.74762079999999, 42.8518007]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364468404?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=OcvMwcd6JNNTMtIEFZoFLw%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'San Jose, CA',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364467390?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=WlewMMR5WiFbiUUMPovnkw%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.8852525, 37.33874]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Texas, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608136?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=RvBSCCLKXj5rb56GvrQGcw%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-99.9018131, 31.9685988]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Illinois, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605652?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=byY2Q63QY9eW5hwkmWayPQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3985283, 40.6331249]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Scottsdale, AZ',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364470064?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=HE8rxQpN%2FlIHjfdcs1rmQw%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9260519, 33.4941704]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Entry-Level Data Analyst',
#     'company': 'The Federal Savings Bank',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/entry-level-data-analyst-at-the-federal-savings-bank-3364619835?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=mSeYZpsdkF8rdX9NNHHzJQ%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364466578?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=b0%2F7rt%2B06q4jY5dy7yh6LA%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6123884, 39.4354087]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Greater Scranton Area',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359603975?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=0YSkDvVsq7yhw8xUec2b9g%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.66241219999999, 41.408969]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Tennessee, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359607287?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=rnJKZAw5eiueylXdzmyikw%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.5804473, 35.5174913]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Indiana, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608137?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=IWWsWAsZywFkq%2Fpr7qProw%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.1349019, 40.2671941]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'London Approach',
#     'work_environment': 'onsite',
#     'location': 'Franklin, TN',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-london-approach-3358861203?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=pX3s2aVFgzfzdfLL7CmgSw%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.8688899, 35.9250637]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wisconsin, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605653?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=k%2B4PoTizjuduF6Bv1EIHhQ%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7878678, 43.7844397]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Virginia, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359604765?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=cEnvDnyBPaGdIw4BXVWz6A%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.6568942, 37.4315734]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Omaha, NE',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364469255?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=MTU51kJEQwON9PEHxlIvWA%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.9345034, 41.2565369]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wilmington, DE',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359606410?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=PqkXuItZQt26iTuZaITOAg%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-75.5483909, 39.744655]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Annapolis, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357037326?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=qGAZxTBvXEdLEAahkVwgkg%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4921829, 38.9784453]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357036349?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=pLEmHxfeCvClFHjrER7ImA%3D%3D&position=18&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6123884, 39.4354087]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': "Chicago Teachers' Pension Fund",
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-19',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-chicago-teachers-%E2%80%8B-pension-fund-3367612394?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=0Gt0bKTEKAD3OPVfkJ10Xg%3D%3D&position=19&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'FreightPlus',
#     'work_environment': 'onsite',
#     'location': 'Quincy, MA',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-freightplus-3369469960?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=rdBxV1wUVepjT5HGj4zLNA%3D%3D&position=20&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.0022705, 42.2528772]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Lockheed Martin',
#     'work_environment': 'onsite',
#     'location': 'Manassas, VA',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-lockheed-martin-3371249347?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=C7p8DNvu1KjBkrqcXMcOsQ%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.47526669999999, 38.7509488]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Valon',
#     'work_environment': 'onsite',
#     'location': 'New York, NY',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-valon-3365948152?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=3mW1J5ZJNxerVviZQAYFHA%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0059728, 40.7127753]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'MV Realty',
#     'work_environment': 'onsite',
#     'location': 'Delray Beach, FL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-mv-realty-3360506601?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=ukLKD7ftdewVR0FHw4Mr6A%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-80.0728201, 26.4614625]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Analyst (Global Data and Analytics)',
#     'company': 'Circle K',
#     'work_environment': 'onsite',
#     'location': 'Tempe, AZ',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/analyst-global-data-and-analytics-at-circle-k-3371237584?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=eINqiEEGvrSjdGnsRWP23g%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400054, 33.4255104]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Selby Jennings',
#     'work_environment': 'onsite',
#     'location': 'Houston, TX',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-selby-jennings-3370840165?refId=EIdhXJ8NOuRNpJdlO%2ByZKQ%3D%3D&trackingId=KT8wW88mNHrlYoxbSpFiEQ%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.3698028, 29.7604267]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364468404?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=iqGU%2FW5RJZ7BNLZCR1w2aA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Buffalo-Niagara Falls Area',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364471019?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=L9GKklmWP6pc92U42nVCew%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-78.74762079999999, 42.8518007]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'San Jose, CA',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364467390?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=te2h%2FqhHWtc7pqfqDKX1vw%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.8852525, 37.33874]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Texas, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608136?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=lbjeLdwVqhC9u6WU1CLh5w%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-99.9018131, 31.9685988]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Illinois, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605652?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=11da%2FCO2ygCXKix%2FBQHd0g%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3985283, 40.6331249]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Scottsdale, AZ',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364470064?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=LFlZ6a6jovHURNiSlMRTFA%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9260519, 33.4941704]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Entry-Level Data Analyst',
#     'company': 'The Federal Savings Bank',
#     'work_environment': 'onsite',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/entry-level-data-analyst-at-the-federal-savings-bank-3364619835?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=VBoj1dORo0s8tm3hzJ8dUg%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Greater Scranton Area',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359603975?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=QwJX8rUItCAhTB%2BoNNXn8A%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.66241219999999, 41.408969]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364466578?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=SFXY4YjZZ8XqRNMYxHojEA%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6123884, 39.4354087]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Tennessee, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359607287?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=kBbLoHxZ7e9cvND1hmsCWQ%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.5804473, 35.5174913]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Indiana, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359608137?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=J7mTQklF5IRdmMDiF490rw%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.1349019, 40.2671941]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wisconsin, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359605653?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=%2BCwJRJArW0tZQueS6%2FLC%2Fg%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7878678, 43.7844397]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Virginia, United States',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359604765?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=qaOwXXjsWOvP88Ifp0%2B7uw%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.6568942, 37.4315734]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'London Approach',
#     'work_environment': 'onsite',
#     'location': 'Franklin, TN',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-london-approach-3358861203?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=j5RchePESK46w%2Bsb1qPa5w%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-86.8688899, 35.9250637]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - Recent Graduate',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Omaha, NE',
#     'posted_date': '2022-11-22',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-recent-graduate-at-paypal-3364469255?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=hHUw3XnXEhXfMRm78viPJA%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.9345034, 41.2565369]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Lockheed Martin',
#     'work_environment': 'onsite',
#     'location': 'Manassas, VA',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-lockheed-martin-3371249347?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=xnggtLHx5spPNQtsyznijA%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.47526669999999, 38.7509488]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Wilmington, DE',
#     'posted_date': '2022-11-17',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3359606410?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=wtRTSptUIeJwWmJXeRT%2FPA%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-75.5483909, 39.744655]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Annapolis, MD',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-paypal-3357037326?refId=hTNgCUL2yc24g6rYCf8srg%3D%3D&trackingId=eB9pskRrwxITUFwUtSToWw%3D%3D&position=18&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4921829, 38.9784453]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'PayPal',
#     'work_environment': 'onsite',
#     'location': 'Timonium, MD',
#     'posted_date': '2022-11-16',
# ...
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'ReUp Education',
#     'work_environment': 'remote',
#     'location': 'Austin, TX',
#     'posted_date': '2022-10-25',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-reup-education-3330231332?refId=i90Urwyy4HkDMHgpM3Ht3Q%3D%3D&trackingId=kYTRVFTn%2BjLJThdosy2K3A%3D%3D&position=20&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.7430608, 30.267153]}},
#   {'type': 'Feature',
#    'properties': {'title': 'SQL Data Analyst',
#     'company': 'Cypress HCM',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-15',
#     'link': 'https://www.linkedin.com/jobs/view/sql-data-analyst-at-cypress-hcm-3355806630?refId=i90Urwyy4HkDMHgpM3Ht3Q%3D%3D&trackingId=MdVNv1VBK%2FExOef94lBf7g%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Precision Technologies',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-09',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-precision-technologies-3344805292?refId=i90Urwyy4HkDMHgpM3Ht3Q%3D%3D&trackingId=lNSd5WWNKFSzZw3zybC%2BUQ%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Tsunami Express Car Wash',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-31',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-tsunami-express-car-wash-3328076726?refId=i90Urwyy4HkDMHgpM3Ht3Q%3D%3D&trackingId=mo3LSTVUEDxsW8kWJvqz5Q%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'M&S Consulting',
#     'work_environment': 'remote',
#     'location': 'Charlotte, NC',
#     'posted_date': '2022-11-01',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-m-s-consulting-3339081565?refId=i90Urwyy4HkDMHgpM3Ht3Q%3D%3D&trackingId=XAC7haZaIj5Ju3rvN5cSLw%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8431267, 35.2270869]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Blend360',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-27',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-blend360-3327602222?refId=i90Urwyy4HkDMHgpM3Ht3Q%3D%3D&trackingId=m1eJbDTLRzuLP5LifM8Y7Q%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst I (entry level)',
#     'company': 'Oracle',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-27',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-i-entry-level-at-oracle-3327334666?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=bb3Pq8j0Z%2Fpp%2FwpTZdnJFQ%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Good Apple',
#     'work_environment': 'remote',
#     'location': 'Chicago, IL',
#     'posted_date': '2022-10-25',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-good-apple-3322134836?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=rv%2B66Sc%2Bx1bwqAy9IjrcUA%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6297982, 41.8781136]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Adfire Health',
#     'work_environment': 'remote',
#     'location': 'New York City Metropolitan Area',
#     'posted_date': '2022-11-15',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-adfire-health-3354914878?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=WNCM0tFntIRTAQZRU84ymg%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0059544, 40.7127761]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Medix™',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-28',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-medix%E2%84%A2-3328072646?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=wrJltEGcMhppaNhR%2ByEduw%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Mainz Brady Group',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-16',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-mainz-brady-group-3357019508?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=CfYWf%2FxtpaspCTApD7cPow%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'ADT Solar',
#     'work_environment': 'remote',
#     'location': 'Boston, MA',
#     'posted_date': '2022-11-15',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-adt-solar-3361518635?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=g%2BJ0FYogfVqhUhyJ7z1M6A%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.0588801, 42.3600825]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Northrop Grumman Federal Credit Union',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-27',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-northrop-grumman-federal-credit-union-3327331924?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=uLGzb8g6YrM%2FO8hr7v31ow%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Storm2',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-storm2-3321260918?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=it8xShHCFkzu2QW80EBjXw%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Launch Consulting Group',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-07',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-launch-consulting-group-3341275864?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=qi8SZ7R7w6gdjsSicWfJsg%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Agility Partners',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-01',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-agility-partners-3339536100?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=AE1zKWUJR1zSXADr%2BzbGrQ%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Azenta Life Sciences',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-08',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-azenta-life-sciences-3348403099?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=W2nJN1t5avIj7vgmhnpN7w%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Atmosfy',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-26',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-atmosfy-3325886772?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=%2FrsVDB7pAQTveRwqRz4%2F9Q%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'EdgeLink',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-25',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-edgelink-3325848323?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=ziJ7eqLKZx%2F%2FGiRkAP0LBA%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Technology Ventures',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-28',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-technology-ventures-3331705813?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=B1y0wpmIoz%2BmyAqqoVvs4A%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Distinct North America',
#     'work_environment': 'remote',
#     'location': 'New York, United States',
#     'posted_date': '2022-10-25',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-distinct-north-america-3329826139?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=d8yWh2E3vFaoTFzEJTLgxw%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0059728, 40.7127753]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'ClarisHealth',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-08',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-clarishealth-3348315857?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=4b39CnkREplC9cLNt1J9%2BQ%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Analyst - Data Visualization',
#     'company': 'Trusted Talent',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-26',
#     'link': 'https://www.linkedin.com/jobs/view/analyst-data-visualization-at-trusted-talent-3326570585?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=1dO9tUVVNrMIbSG19ydBdQ%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Analyst, Data and Analytics',
#     'company': 'CafeMedia',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-21',
#     'link': 'https://www.linkedin.com/jobs/view/analyst-data-and-analytics-at-cafemedia-3369457251?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=7TTYnb05NgTgmhHe79A54w%3D%3D&position=18&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst - (Remote - US)',
#     'company': 'Mediavine',
#     'work_environment': 'remote',
#     'location': 'Dallas, TX',
#     'posted_date': '2022-11-23',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-remote-us-at-mediavine-3371287252?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=s1Kex2kRIuoGFsNcuufGjQ%3D%3D&position=19&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-96.7969879, 32.7766642]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'ReUp Education',
#     'work_environment': 'remote',
#     'location': 'Austin, TX',
#     'posted_date': '2022-10-25',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-reup-education-3330231332?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=BgxDapRKG5uat8JIY9XRrw%3D%3D&position=20&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.7430608, 30.267153]}},
#   {'type': 'Feature',
#    'properties': {'title': 'SQL Data Analyst',
#     'company': 'Cypress HCM',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-15',
#     'link': 'https://www.linkedin.com/jobs/view/sql-data-analyst-at-cypress-hcm-3355806630?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=rdcbu%2FaNP1wb1FGOHybcHw%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Precision Technologies',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-11-09',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-precision-technologies-3344805292?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=ZjeN3b%2Fj6ibpjcD632OQCA%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Tsunami Express Car Wash',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-31',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-tsunami-express-car-wash-3328076726?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=84EwaeVQfbQ%2BMSD6T8kKeg%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'M&S Consulting',
#     'work_environment': 'remote',
#     'location': 'Charlotte, NC',
#     'posted_date': '2022-11-01',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-m-s-consulting-3339081565?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=y5XcpLYMeeTuOxh4sxL0dw%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8431267, 35.2270869]}},
#   {'type': 'Feature',
#    'properties': {'title': 'Data Analyst',
#     'company': 'Blend360',
#     'work_environment': 'remote',
#     'location': 'United States',
#     'posted_date': '2022-10-27',
#     'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-blend360-3327602222?refId=5Kfa8il8F%2BldK85JCQatcg%3D%3D&trackingId=uiz3dcYBBxpyUI1wNTVukA%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#   ...]}

# %%
# Save it to a .js file for dashboard creation
output_filename = 'data/jobs_usa.js'
with open(output_filename, 'wt') as output_file:
    output_file.write('var dataset = ')
    json.dump(geojson, output_file, indent=2)

# %%
# Write geojson to a file in Python using json.dump() 

# Serializing json
json_object = json.dumps(geojson, indent=2)
 
# Writing to sample.json
with open("data/sample.json", "w") as outfile:
    outfile.write(json_object)

# %%
# Write the df to SQLite database
conn = sql.connect('data/sample.json.sqlite')
sample.json.to_sql('upjob_stats', conn, if_exists='replace', index=False)
# pd.read_sql('select * from job_stats', conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 # Write the df to SQLite database
#       2 conn = sql.connect('data/sample.json.sqlite')
# ----> 3 sample.json.to_sql('upjob_stats', conn, if_exists='replace', index=False)
#
# NameError: name 'sample' is not defined
